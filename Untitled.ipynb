# %%
# importing above defined libraries to 
# implement the functionalities 
from PIL import ImageGrab, ImageOps 
import pyautogui 
import time 
import numpy as np 
	
class cordinates(): 

	# coordinates of replay button to start the game 
	replaybutton =(360, 214) 
	# this coordinates represent the top-right coordinates 
	# that will be used to define the front box 
	dinasaur = (149, 239 ) 
	
def restartGame(): 

	# using pyautogui library, we are clicking on the 
	# replay button without any user interaction 
	pyautogui.click(cordinates.replaybutton) 

	# we will keep our Bot always down that 
	# will prevent him to get hit by bird 
	pyautogui.keyDown('down') 

def press_space(): 

	# releasing the Down Key 
	pyautogui.keyUp('down') 

	# pressing Space to overcome Bush 
	pyautogui.keyDown('space') 

	# so that Space Key will be recognized easily 
	time.sleep(0.05) 

	# printing the "Jump" statement on the 
	# terminal to see the current output 
	print("jump") 
	time.sleep(0.10) 

	# releasing the Space Key 
	pyautogui.keyUp('space') 

	# again pressing the Down Key to keep my Bot always down 
	pyautogui.keyDown('down') 

def imageGrab(): 
	# defining the coordinates of box in front of dinosaur 
	box = (cordinates.dinasaur[0]+30, cordinates.dinasaur[1], 
		cordinates.dinasaur[0]+120, cordinates.dinasaur[1]+2) 

	# grabbing all the pixels values in form of RGB tupples 
	image = ImageGrab.grab(box) 

	# converting RGB to Grayscale to 
	# make processing easy and result faster 
	grayImage = ImageOps.grayscale(image) 

	# using numpy to get sum of all grayscale pixels 
	a = np.array(grayImage.getcolors()) 

	# returning the sum 
	print(a.sum()) 
	return a.sum() 
	
	

# function to restart the game 
restartGame() 
while True: 
	# 435 is the sum of white pixels values of box. 
	# You may get different value is you are taking bigger 
	# or smaller box than the box taken in this article. 
	# if value returned by "imageGrab" function is not equal to 435, 
	# it means either bird or bush is coming towards dinosaur 
	if(imageGrab()!= 435): 
		press_space() 
		# time to recognize the operation performed by above function 
		time.sleep(0.1)

# %%
from numpy import *
from PIL import ImageGrab,ImageOps
import pyautogui as py
 
def pressSpace():
    py.keyDown('space')
    py.keyUp('space')
 
def IMG():
    Box=(167,390,270,420)    #Use your own Coordinates here
    image=ImageGrab.grab(Box)
    image=ImageOps.grayscale(image)
    arr=array(image.getcolors())
    return(arr.sum())
 
def main():
    print("Starting Game.....")
    x=0
    while(1):
        if(IMG()!=3337):
            pressSpace()
            x=x+1
            print("     Jumping "+str(x)+" times")
 
main()
# Out:
# Starting Game.....
#      Jumping 1 times
#      Jumping 2 times
#      Jumping 3 times
#      Jumping 4 times
#      Jumping 5 times
#      Jumping 6 times
#      Jumping 7 times
#      Jumping 8 times
#      Jumping 9 times
#      Jumping 10 times
#      Jumping 11 times
#      Jumping 12 times
#      Jumping 13 times
#      Jumping 14 times
#      Jumping 15 times
#      Jumping 16 times
#      Jumping 17 times
#      Jumping 18 times
#      Jumping 19 times
#      Jumping 20 times
#      Jumping 21 times
#      Jumping 22 times
#      Jumping 23 times
#      Jumping 24 times
#      Jumping 25 times
#      Jumping 26 times
#      Jumping 27 times
#      Jumping 28 times
#      Jumping 29 times
#      Jumping 30 times
#      Jumping 31 times
#      Jumping 32 times
#      Jumping 33 times
#      Jumping 34 times
#      Jumping 35 times
#      Jumping 36 times
#      Jumping 37 times
#      Jumping 38 times
#      Jumping 39 times
#      Jumping 40 times
#      Jumping 41 times
#      Jumping 42 times
#      Jumping 43 times
#      Jumping 44 times
#      Jumping 45 times
#      Jumping 46 times
#      Jumping 47 times
#      Jumping 48 times
#      Jumping 49 times
#      Jumping 50 times
#      Jumping 51 times
#      Jumping 52 times
#      Jumping 53 times
#      Jumping 54 times
#      Jumping 55 times
#      Jumping 56 times
#      Jumping 57 times
#      Jumping 58 times
#      Jumping 59 times
#      Jumping 60 times
#      Jumping 61 times
#      Jumping 62 times
#      Jumping 63 times
#      Jumping 64 times
#      Jumping 65 times
#      Jumping 66 times
#      Jumping 67 times
#      Jumping 68 times
#      Jumping 69 times
#      Jumping 70 times
#      Jumping 71 times
#      Jumping 72 times
#      Jumping 73 times
#      Jumping 74 times
#      Jumping 75 times
#      Jumping 76 times
#      Jumping 77 times
#      Jumping 78 times
#      Jumping 79 times
#      Jumping 80 times
#      Jumping 81 times
#      Jumping 82 times
#      Jumping 83 times
#      Jumping 84 times
#      Jumping 85 times
#      Jumping 86 times
#      Jumping 87 times
#      Jumping 88 times
#      Jumping 89 times
#      Jumping 90 times
#      Jumping 91 times
#      Jumping 92 times
#      Jumping 93 times
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-041311e8de02> in <module>
#      23             print("     Jumping "+str(x)+" times")
#      24
# ---> 25 main()
#
# <ipython-input-4-041311e8de02> in main()
#      19     while(1):
#      20         if(IMG()!=3337):
# ---> 21             pressSpace()
#      22             x=x+1
#      23             print("     Jumping "+str(x)+" times")
#
# <ipython-input-4-041311e8de02> in pressSpace()
#       4
#       5 def pressSpace():
# ----> 6     py.keyDown('space')
#       7     py.keyUp('space')
#       8
#
# C:\Anaconda3\lib\site-packages\pyautogui\__init__.py in keyDown(key, pause, logScreenshot, _pause)
#    1123     platformModule._keyDown(key)
#    1124
# -> 1125     _autoPause(pause, _pause)
#    1126
#    1127 def keyUp(key, pause=None, logScreenshot=None, _pause=True):
#
# C:\Anaconda3\lib\site-packages\pyautogui\__init__.py in _autoPause(pause, _pause)
#     240     elif _pause:
#     241         assert isinstance(PAUSE, int) or isinstance(PAUSE, float)
# --> 242         time.sleep(PAUSE)
#     243
#     244
#
# KeyboardInterrupt:

# %%
# importing above defined libraries to 
# implement the functionalities 
from PIL import ImageGrab, ImageOps 
import pyautogui 
import time 
import numpy as np 
class cordinates():
    reply=(340,375)
    dino=(190,396)

def restartGame(): 
    pyautogui.click(cordinates.reply)
    pyautogui.keyDown('down') 

def press_space(): 
    pyautogui.keyUp('down') 
    time.sleep(0.05) 
    pyautogui.keyDown('space') 
    time.sleep(0.05) 
    print("jump") 
    time.sleep(0.10) 
    pyautogui.keyUp('space') 
    pyautogui.keyDown('down') 

def imageGrab(): 
    box = (cordinates.dinasaur[0]+30, cordinates.dinasaur[1], cordinates.dinasaur[0]+10, cordinates.dinasaur[1]+15) 
    image = ImageGrab.grab(box) 
    grayImage = ImageOps.grayscale(image) 
    a = np.array(grayImage.getcolors()) 
    print(a.sum()) 
    return a.sum() 

restartGame() 
while True: 
    if(imageGrab()!= 427): 
        press_space() 
        time.sleep(0.1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-3da9e6259edb> in <module>
#      33 restartGame()
#      34 while True:
# ---> 35     if(imageGrab()!= 427):
#      36         press_space()
#      37         time.sleep(0.1)
#
# <ipython-input-29-3da9e6259edb> in imageGrab()
#      24
#      25 def imageGrab():
# ---> 26     box = (cordinates.dinasaur[0]+30, cordinates.dinasaur[1], cordinates.dinasaur[0]+10, cordinates.dinasaur[1]+15)
#      27     image = ImageGrab.grab(box)
#      28     grayImage = ImageOps.grayscale(image)
#
# AttributeError: type object 'cordinates' has no attribute 'dinasaur'
